# %%
import glob
import pandas as pd
import re

# %%
with open("001_n.txt", "r") as f:
    data = f.readlines()

# %%
df = pd.DataFrame(data)
df.columns = ['script']

# %%
df[30:40]
# Out:
#                                         script
# 30  몽\tRoger. (교신 끝내고는) 2006년? 하.. (고개를 돌려 어\n
# 31                                          \n
# 32                                 딘가를 바라보는)\n
# 33                                          \n
# 34                                        \t\n
# 35                                          \n
# 36             \t카메라 팬하며 우주공간에서 지구로, 지구에서 아시\n
# 37                                          \n
# 38             아 대륙, 아시아에서 한국으로 빠른 디졸브로 좁혀지는\n
# 39                                          \n

# %%
df = df[df.script != "\n"]

# %%
# text = "혜미\tRoger. (교신 끝내고는) 2006년? 하.. (고개를 돌려 어\n"
text = "센터요원 (영어 off) 인공위성 일부분.\n	"

# %%
len(re.findall(r"^\w+\s[()]", text))
# Out:
# 1

# %%
def isTalk(a_string):
    p1 = len(re.findall(r"^\w+\t", a_string))
    p2 = len(re.findall(r"^\w+\s+[()]", a_string))
    res = p1 + p2
    if res > 0:
        return True
    else:
        return False

# %%
df['isTalk'] = df['script'].map(isTalk)

# %%
df.reset_index(drop=True, inplace=True)

# %%
chars = ['순재', '준하', '문희', '해미', '민용', '민호', '윤호', '찬성', '민정']

# %%
text = "순재 도대체가 말이야..\n	"

# %%
any([char in text.split() for char in chars])
# Out:
# True

# %%
df['counter'] = 0

counter = 0

for i in range(0, len(df)):
    current_is_talk = df.ix[i]['isTalk']
    if (current_is_talk == True) | (df.ix[i].script[0] == "씬") | (any([char in df.ix[i].script.split() for char in chars])):
        counter = counter + 1
    df.set_value(i, 'counter', counter)

# for i in range(1, len(df)):
#     current_is_talk = df.ix[i]['isTalk']
#     next_is_talk = df.ix[i-1]['isTalk']
#     if next_is_talk != next_is_talk:
#         counter = counter + 1
#     df.set_value(i, 'counter', counter)

# %%
df
# Out:
#                                              script isTalk  counter
# 0                               ﻿1 회 ㅣ 2006-11-06\n  False        0
# 1                           씬/1\t우주 공간 + 관제센터(야외)\n  False        1
# 2                   \t별이 가득한 광대한 우주공간 보이고 우주선들 빠르\n  False        1
# 3             게 날아가는 모습 보이다 공간 안에 멈춰서 있는 우주선이 보이고\n  False        1
# 4              우주복을 입은 MC몽(준이의 성인역)이 우주선 수리하며 관제센\n  False        1
# 5                터 요원과 교신하는. 몽의 우주복 헬멧창에 지구가 비친다.\n  False        1
# 6           센터요원\t(영어로 off) 준, 열 제어판 손상은 어느 정도인가?\n   True        2
# 7                                  몽\t(영어) 조사중이다.\n   True        3
# 8               센터요원      (영어로) 육안으로 보이는 외상이 있는가?\n   True        4
# 9    몽            (영어로) 없다. 그런데 아까 우리와 부딪친 게 뭐였나?\n   True        5
# 10                   센터요원      (영어 off) 인공위성 일부분.\n   True        6
# 11                \t2006년에 한국에서 쏜 아리랑위성 잔해로 파악됐다.\n  False        6
# 12          몽\t(영어) 2006년? 골동품이네. (웃으며) 2006년이면 내\n   True        7
# ...

# %%
df2 = df[df.script != "\n"]

# %%
df3 = pd.DataFrame(df2.groupby('counter')['script'].apply(list))

# %%
df4 = pd.DataFrame(df3['script'].map(lambda x: "".join(x)))

# %%
df5 = pd.DataFrame(df4['script'].map(lambda x: x.replace("\n\t", " ").replace("\t(", ": (").replace("\t", ": ")))

# %%
def temp_parse_func(a_string):
    if ":" not in a_string:
        new_string = a_string.replace(" (", ": (")
        return new_string
    else:
        return a_string

# %%
df6 = pd.DataFrame(df5.script.map(lambda x: temp_parse_func(x)))

# %%
df6['colon_count'] = df6.script.map(lambda x: x.count(":"))

# %%
df6['first_char'] = df6.script.map(lambda x: x[0])

# %%
df6[(df6.first_char == "씬") | (df6.first_char == ":")]
# Out:
#                                                     script  colon_count  \
# counter
# 1        씬/1: 우주 공간 + 관제센터(야외) 별이 가득한 광대한 우주공간 보이고 우주선들...            1
# 13       씬/2: 사진관 스튜디오 (D, 야외) 화면 블랙에서 밝아지면 아기 몽(준이)의 시...            1
# 14                    : 문희와 해미 얼굴이 먼저 떠있다. 자막) 2006년 10월\n            1
# 24                                  : 이때 오줌발이 순재 얼굴을 쏜다.\n            1
# 43       씬/3: 사진관 밖 (D, 야외) 해미가 나오는데 민용과 신지가 작은 소리로 툭닥거...            1
# 49       씬/4:       사진관 스튜디오 (D, 야외)       카메라 프레임으로 보이...            1
# 65       씬/5: 학교 앞 (D, 야외) 남녀 학생들 시끌시끌 등교하고 있고, 종소리 울리고...            1
# 66       씬/6: 교무실  (D, 야외) 교감이 교사들 앞에서 민정을 인사시킨다. 민용은 체...            1
# 81       씬/7: 교실 (D, 야외) 민정, 교단에 서 있고 반 아이들 윤호빼고 다 앉아있\...            1
# 101                         : 반장 말이 맞아 원칙은 원칙이니까 윤호 지각..\n            1
# 111      씬/8: 병원 외경 (D, 야외) <이순재 여성전용 한방병원> 간판이 붙어있는 4층...            1
# 112                                씬/9: 거실 (D) 순재가 들어온다.\n            1
# ...

# %%
df6.ix[140:160]
# Out:
#                                                     script  colon_count  \
# counter
# 140      문희: 어~ (벗겨지면 파마용 롤이 붙어있다) 개성댁이랑 미장원에서 머리 말다 잠깐...            1
# 141                    순재: 파마를 왜? 설마 뽀글뽀글한 뽀글파마 그거 하는거야?\n            1
# 142                                               문희: 예.\n            1
# 143                순재: (화내는) 아 내가 싫어하는 거 알면서 왜 뽀글파마를\n해?\n            1
# 144                           문희: 그게 젤 편해. 한번 하면 만사 편한걸.\n            1
# 145      순재: 그래도 내가 싫어하는데 왜 해! 나랑 상의도 없이! 아니 오늘따라 아들놈이나...            1
# 146                     문희: 다시 풀어달라 그래요? 풀어도 돈은 다 내야 돼..\n            1
# 147                               순재: 아우 씨! (화가 나서 나가는) \n            1
# 148                    씬/12: 학교 앞 (D,야외) +  학교 옥상 (D,야외)\n            1
# 149             : 수업 마친 학생들 삼삼오오 걸어오고 윤호 걸어오는\n데 핸드폰 울리는\n            1
# 150      윤호: 예 찬성과 승현, 옥상에 있다. 승현은 폼 잡으며 각 세우고 서 있고 찬성이...            1
# 151                                   찬성: 야 이윤호 나 황찬성이다.\n            1
# ...

# %%
df.ix[200:300].script
# Out:
# 200                                        같다 미안~\n
# 201                  \t반장 말이 맞아 원칙은 원칙이니까 윤호 지각..\n
# 202             윤호\t와 선생님이 이랬다 저랬다 하시구 어우~ (혈압 오른\n
# 203                                   다는 듯 목 돌리는)\n
# 204           민정\t아...(당황해서) 그럼..(애교스럽게 웃으며) 첫날이니\n
# 205                          까 기분으로 한번만 봐줄까 반자...\n
# 206                        민호\t선생님? (강력한 눈빛을 보낸다)\n
# 207           민정\t(기에 눌려) 안되겠지 이윤호 지각..(표시하고) 내일부\n
# 208                                     터 늦지 마세요.\n
# 209           윤호\t(표정. 어우~ 하며 열 받는 듯 의자를 뒤로 확 민다)\n
# 210          민정\t(표정) 그럼 내 소개 할께.. (출석부 덮으며 양쪽 눈치\n
# 211                                       를 살피는데)\n
# 212                           민호\t(윤호 슥 째리며 돌아보는)\n
# 213                 윤호\t(민호 향해 엿 먹으라는 표시의 주먹 날린다)\n
# 214           민정\t(칠판에 이름을 쓰면서 겁에 질려 OFF) 아 분위기 왜\n
# 215                                         이래...\n
# 216                        엄마 어떡해 남자 고딩들 너무 무서워~~\n
# 217                            씬/8\t병원 외경 (D, 야외)\n
# ...

# %%
t = "찬성\t야 우리 지금 옥상에 있거든? 쉬끼 10초안에 튀어 와\n"

# %%
def isTalk(a_string):
    p1 = len(re.findall(r'^\w+\t', a_string))
    p2 = len(re.findall(r'^\w+\s+[()]', a_string))
    res = p1 + p2
    if res > 0:
        return True
    else:
        return False

# %%
def isEnd()

# %%
df['isTalk2'] = df.script.map(isTalk)

# %%
df['endStart'] = ""

for i in range(1, len(df)):
    prev_end = df.ix[i-1].script[-1]
    current_start = df.ix[i].script[0]
    df.set_value(i, 'endStart', "".join([prev_end, current_start]))

# %%
df[df.isTalk2 == True]
# Out:
#                                              script isTalk  counter isTalk2  \
# 6           센터요원\t(영어로 off) 준, 열 제어판 손상은 어느 정도인가?\n   True        2    True
# 7                                  몽\t(영어) 조사중이다.\n   True        3    True
# 8               센터요원      (영어로) 육안으로 보이는 외상이 있는가?\n   True        4    True
# 9    몽            (영어로) 없다. 그런데 아까 우리와 부딪친 게 뭐였나?\n   True        5    True
# 10                   센터요원      (영어 off) 인공위성 일부분.\n   True        6    True
# 12          몽\t(영어) 2006년? 골동품이네. (웃으며) 2006년이면 내\n   True        7    True
# 14                센터요원      (영어 off) 그래? (웃는) 이상.\n   True        8    True
# 15       몽\tRoger. (교신 끝내고는) 2006년? 하.. (고개를 돌려 어\n   True        9    True
# 21           몽\t(NARR) 지금으로부터 28년전인 2006년..내가 태어난\n   True       10    True
# 28   몽            (NARR) 대한민국의 2006년은 노무현대통령 5년임기\n   True       11    True
# 36          몽\t(NARR) 그 격동과 좌절의 2006년 늦여름.. 나는 서울\n   True       12    True
# ...
